# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Assessment for comptencey ECU-ITAI-1-06

# %% [markdown]
# # name:kerolos mohsen

# %% [markdown]
# # junior:J1

# %% [markdown]
# # Second learning outcome: Write a set of codes that support the program.

# %% [markdown]
# Q1: Write a set of codes in order according to the solution plan developed to solve the problem and ensure to put some comments to explain the code first read the file using pandas

# %% [markdown]
# ![WhatsApp%20Image%202024-03-28%20at%2000.51.24_444a98b9.jpg](attachment:WhatsApp%20Image%202024-03-28%20at%2000.51.24_444a98b9.jpg)

# %%
# !pip install pandas

import pandas as pd

df = pd.read_csv(r"")

# %% [markdown]
# Q2. present the first 5 rows of the data

# %%
df.head()

# %% [markdown]
# Q3. remove the null values for each column in data

# %%
df.isna().sum()

#  to remove the row that have null value (recomended)
df = df.dropna()

df.isnull().sum()

# %% [markdown]
# Q4. Train the model

# %%
# Define X by dropping the "last" column
x = df.drop("SalePrice", axis=1)

# Define y as the "last" column
y = df["SalePrice"]

from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=55)



# regresion

from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import mean_squared_error,r2_score

tree=DecisionTreeRegressor()

tree.fit(x_train,y_train)

y_pred=tree.predict(x_test)

# %% [markdown]
# test it and evauate using evaluation matrix

# %%
m=mean_squared_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)

print("m:",m)
print("r2:",r2)

# %% [markdown]
# # Fourth learning outcome: Test the program to make sure the problem is resolved.

# %% [markdown]
# #### Example 1

# %%
my_dict = {'galal':23, "fathy";30, "anwar":23}
my_dict
# Out:
#   File "<ipython-input-12-c0f6908edbc5>", line 1
#     my_dict = {'galal':23, "fathy";30, "anwar":23}
#                                   ^
# SyntaxError: invalid syntax

# %%
my_dict ={
    "galal":23,
    "fathy":30,
    "anwar":23 
}

my_dict
# Out:
# {'galal': 23, 'fathy': 30, 'anwar': 23}

# %% [markdown]
# ![WhatsApp%20Image%202024-03-28%20at%2000.51.24_444a98b9.jpg](attachment:WhatsApp%20Image%202024-03-28%20at%2000.51.24_444a98b9.jpg)

# %% [markdown]
# #### Example 2

# %%
def foo():
 for i in range(10)
    print(i)
  print('done')
# Out:
#   File "<tokenize>", line 4
#     print('done')
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
def foo():
    for i in range(10):
        print(i)
    print('done')

# %% [markdown]
# ![WhatsApp%20Image%202024-03-28%20at%2000.51.24_444a98b9.jpg](attachment:WhatsApp%20Image%202024-03-28%20at%2000.51.24_444a98b9.jpg)

# %% [markdown]
# #### Example 3

# %%
x=0
if x = 5
print("x is 5")
# Out:
#   File "<ipython-input-17-fd62c12a7536>", line 2
#     if x = 5
#          ^
# SyntaxError: invalid syntax

# %%
x=0
if x ==5:
    print("x is 5")

# %% [markdown]
# ![WhatsApp%20Image%202024-03-28%20at%2000.51.24_444a98b9.jpg](attachment:WhatsApp%20Image%202024-03-28%20at%2000.51.24_444a98b9.jpg)

# %% [markdown]
# # Thank You Best Wihes
# # Prep by:
# ![WhatsApp%20Image%202024-03-28%20at%2000.43.17_d240771a.jpg](attachment:WhatsApp%20Image%202024-03-28%20at%2000.43.17_d240771a.jpg)
